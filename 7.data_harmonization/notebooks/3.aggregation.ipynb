# %% [markdown]
# # Aggregate feature selected profiles

# %% [markdown]
# ## Import libraries

# %%
import pathlib

import pandas as pd
from pycytominer import aggregate

# %% [markdown]
# ## Set paths and variables

# %%
# set paths
input_profile_dir = pathlib.Path(
    "../data/CP_scDINO_features/combined_CP_scDINO_norm_fs.parquet"
).resolve(strict=True)
output_profile_dir = pathlib.Path(
    "../data/CP_scDINO_features/combined_CP_scDINO_norm_fs_aggregated.parquet"
).resolve()
fs_df = pd.read_parquet(input_profile_dir)
fs_df.head()
# Out:
#    Metadata_plate Metadata_Well  Metadata_number_of_singlecells  \
# 0               1          C-10                             150
# 1               1          C-10                             150
# 2               1          C-10                             150
# 3               1          C-10                             150
# 4               1          C-10                             150
#
#   Metadata_compound Metadata_dose Metadata_control Metadata_ImageNumber  \
# 0     Staurosporine         78.13             test                   11
# 1     Staurosporine         78.13             test                   11
# 2     Staurosporine         78.13             test                   11
# 3     Staurosporine         78.13             test                   11
# 4     Staurosporine         78.13             test                   11
#
#   Metadata_FOV Metadata_Time  Metadata_Cells_Number_Object_Number  ...  \
# 0         0003          10.0                                  1.0  ...
# 1         0003          10.0                                 15.0  ...
# 2         0003          10.0                                 16.0  ...
# 3         0003          10.0                                 26.0  ...
# 4         0003          10.0                                 37.0  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           0.455650                           0.394903
# 1                           1.055771                           0.704042
# 2                          -0.834577                           0.310103
# 3                          -1.519428                           1.510967
# 4                          -1.172900                           0.214924
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                           1.649449                           0.010330
# 1                          -1.417577                           0.262575
# 2                          -0.678053                           1.008923
# 3                          -0.939257                          -0.584025
# 4                           2.372842                          -0.591197
#
#    channel_DNA_cls_feature_95_scDINO channel_DNA_cls_feature_96_scDINO  \
# 0                           0.426311                         -0.339320
# 1                           1.097736                         -1.700848
# 2                          -0.144754                         -1.514908
# 3                           2.944528                         -0.227416
# 4                          -0.304200                          0.505422
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                          1.586745                         -0.362606
# 1                          0.563939                          0.238832
# 2                         -0.609500                          0.447918
# 3                          0.076889                         -1.431668
# 4                         -0.360512                          1.295638
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                          0.811210                         1.215151
# 1                          0.717390                         0.768155
# 2                          1.357684                         1.000216
# 3                         -0.097650                         0.970673
# 4                          1.948911                         0.107559
#
# [5 rows x 2425 columns]

# %% [markdown]
# ## Perform aggregation

# %%
metadata_cols = fs_df.columns[fs_df.columns.str.contains("Metadata")].to_list()
feature_cols = fs_df.columns[~fs_df.columns.str.contains("Metadata")].to_list()

aggregated_df = aggregate(
    fs_df,
    features=feature_cols,
    strata=["Metadata_Well", "Metadata_Time", "Metadata_dose"],
    operation="median",
)
aggregated_df = pd.merge(
    aggregated_df,
    fs_df[metadata_cols],
    how="left",
    on=["Metadata_Well", "Metadata_Time", "Metadata_dose"],
)
# rearrange the columns such that the metadata columns are first
for col in reversed(aggregated_df.columns):
    if col.startswith("Metadata_"):
        tmp_pop = aggregated_df.pop(col)
        aggregated_df.insert(0, col, tmp_pop)

print(aggregated_df.shape)
aggregated_df.to_parquet(output_profile_dir)
aggregated_df.head()
# Out:
# (142040, 2425)
#   Metadata_Well Metadata_Time Metadata_dose  Metadata_plate  \
# 0          C-02           0.0           0.0               1
# 1          C-02           0.0           0.0               1
# 2          C-02           0.0           0.0               1
# 3          C-02           0.0           0.0               1
# 4          C-02           0.0           0.0               1
#
#    Metadata_number_of_singlecells Metadata_compound Metadata_control  \
# 0                             192     Staurosporine         negative
# 1                             192     Staurosporine         negative
# 2                             192     Staurosporine         negative
# 3                             192     Staurosporine         negative
# 4                             192     Staurosporine         negative
#
#   Metadata_ImageNumber Metadata_FOV  Metadata_Cells_Number_Object_Number  ...  \
# 0                    1         0003                                 18.0  ...
# 1                    1         0003                                 21.0  ...
# 2                    1         0003                                 27.0  ...
# 3                    1         0003                                 38.0  ...
# 4                    1         0003                                 41.0  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           0.229693                          -0.149462
# 1                           0.229693                          -0.149462
# 2                           0.229693                          -0.149462
# 3                           0.229693                          -0.149462
# 4                           0.229693                          -0.149462
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                           0.096256                          -0.093128
# 1                           0.096256                          -0.093128
# 2                           0.096256                          -0.093128
# 3                           0.096256                          -0.093128
# 4                           0.096256                          -0.093128
#
#    channel_DNA_cls_feature_95_scDINO channel_DNA_cls_feature_96_scDINO  \
# 0                           0.044964                          0.164799
# 1                           0.044964                          0.164799
# 2                           0.044964                          0.164799
# 3                           0.044964                          0.164799
# 4                           0.044964                          0.164799
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                          0.055467                          0.005083
# 1                          0.055467                          0.005083
# 2                          0.055467                          0.005083
# 3                          0.055467                          0.005083
# 4                          0.055467                          0.005083
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                         -0.242997                         0.102387
# 1                         -0.242997                         0.102387
# 2                         -0.242997                         0.102387
# 3                         -0.242997                         0.102387
# 4                         -0.242997                         0.102387
#
# [5 rows x 2425 columns]
