# %% [markdown]
# # Aggregate feature selected profiles

# %% [markdown]
# ## Import libraries

# %%
import pathlib

import pandas as pd
from pycytominer import aggregate

# %% [markdown]
# ## Set paths and variables

# %%
# set paths
input_profile_dir = pathlib.Path(
    "../data/CP_scDINO_features/combined_CP_scDINO_norm_fs.parquet"
).resolve(strict=True)
output_profile_dir = pathlib.Path(
    "../data/CP_scDINO_features/combined_CP_scDINO_norm_fs_aggregated.parquet"
).resolve()
fs_df = pd.read_parquet(input_profile_dir)

# %% [markdown]
# ## Perform aggregation

# %%
metadata_cols = fs_df.columns[fs_df.columns.str.contains("Metadata")].to_list()
feature_cols = fs_df.columns[~fs_df.columns.str.contains("Metadata")].to_list()

aggregated_df = aggregate(
    fs_df,
    features=feature_cols,
    strata=["Metadata_Well", "Metadata_Time", "Metadata_dose"],
    operation="median",
)
aggregated_df = pd.merge(
    aggregated_df,
    fs_df[metadata_cols],
    how="left",
    on=["Metadata_Well", "Metadata_Time"],
)
# rearrange the columns such that the metadata columns are first
for col in reversed(aggregated_df.columns):
    if col.startswith("Metadata_"):
        tmp_pop = aggregated_df.pop(col)
        aggregated_df.insert(0, col, tmp_pop)

print(aggregated_df.shape)
aggregated_df.to_parquet(output_profile_dir)
aggregated_df.head()
# Out:
# (145489, 2445)
#   Metadata_Well Metadata_Time Metadata_dose_x  Metadata_plate  \
# 0          C-02           0.0             0.0               1
# 1          C-02           0.0             0.0               1
# 2          C-02           0.0             0.0               1
# 3          C-02           0.0             0.0               1
# 4          C-02           0.0             0.0               1
#
#    Metadata_number_of_singlecells Metadata_compound Metadata_dose_y  \
# 0                             178     Staurosporine             0.0
# 1                             178     Staurosporine             0.0
# 2                             178     Staurosporine             0.0
# 3                             178     Staurosporine             0.0
# 4                             178     Staurosporine             0.0
#
#   Metadata_control Metadata_ImageNumber Metadata_FOV  ...  \
# 0         negative                    1         0001  ...
# 1         negative                    1         0001  ...
# 2         negative                    1         0001  ...
# 3         negative                    1         0001  ...
# 4         negative                    1         0001  ...
#
#    channel_DNA_cls_feature_91_scDINO  channel_DNA_cls_feature_92_scDINO  \
# 0                           0.186208                          -0.140797
# 1                           0.186208                          -0.140797
# 2                           0.186208                          -0.140797
# 3                           0.186208                          -0.140797
# 4                           0.186208                          -0.140797
#
#    channel_DNA_cls_feature_93_scDINO  channel_DNA_cls_feature_94_scDINO  \
# 0                            0.04191                          -0.008297
# 1                            0.04191                          -0.008297
# 2                            0.04191                          -0.008297
# 3                            0.04191                          -0.008297
# 4                            0.04191                          -0.008297
#
#    channel_DNA_cls_feature_95_scDINO  channel_DNA_cls_feature_96_scDINO  \
# 0                           0.035978                           0.121764
# 1                           0.035978                           0.121764
# 2                           0.035978                           0.121764
# 3                           0.035978                           0.121764
# 4                           0.035978                           0.121764
#
#   channel_DNA_cls_feature_97_scDINO channel_DNA_cls_feature_98_scDINO  \
# 0                         -0.021929                         -0.020082
# 1                         -0.021929                         -0.020082
# 2                         -0.021929                         -0.020082
# 3                         -0.021929                         -0.020082
# 4                         -0.021929                         -0.020082
#
#   channel_DNA_cls_feature_99_scDINO channel_DNA_cls_feature_9_scDINO
# 0                         -0.140129                         0.142675
# 1                         -0.140129                         0.142675
# 2                         -0.140129                         0.142675
# 3                         -0.140129                         0.142675
# 4                         -0.140129                         0.142675
#
# [5 rows x 2445 columns]
