# %% [markdown]
# # Perform feature selection on normalized data

# %% [markdown]
# ## Import libraries

# %%
import gc
import pathlib
import sys

import pandas as pd
from pycytominer import feature_select
from pycytominer.cyto_utils import output

# %% [markdown]
# ## Set paths and variables

# %%
# directory where normalized parquet file is located
input_file_path = pathlib.Path("../data/4.normalized_data/normalized_profile.parquet")

# directory where the feature selected parquet file is saved to
output_file_path = pathlib.Path(
    "../data/5.feature_selected_data/features_selected_profile.parquet"
)
output_file_path.parent.mkdir(exist_ok=True)

# %% [markdown]
# ## Perform feature selection

# %%
# define operations to be performed on the data
# list of operations for feature select function to use on input profile
feature_select_ops = [
    "variance_threshold",
    "blocklist",
    "drop_na_columns",
    "correlation_threshold",
]

# %%
manual_block_list = [
    "Nuclei_AreaShape_BoundingBoxArea",
    "Nuclei_AreaShape_BoundingBoxMinimum_X",
    "Cells_AreaShape_BoundingBoxArea",
]

# %%
# feature selection parameters
print("Performing feature selection on normalized annotated merged single cells!")

# read in the annotated file
normalized_df = pd.read_parquet(input_file_path)
# perform feature selection with the operations specified
feature_select_df = feature_select(
    normalized_df,
    operation=feature_select_ops,
)

# add "Metadata_" to the beginning of each column name in the list
feature_select_df.columns = [
    "Metadata_" + column if column in manual_block_list else column
    for column in feature_select_df.columns
]
print("Feature selection complete, saving to parquet file!")
# save features selected df as parquet file
output(
    df=feature_select_df,
    output_filename=output_file_path,
    output_type="parquet",
)
# check to see if the shape of the df has changed indicating feature selection occurred
print(feature_select_df.shape)
feature_select_df.head()
# Out:
# Performing feature selection on normalized annotated merged single cells!
# Feature selection complete, saving to parquet file!
# (1700, 882)
#    NMF_plate NMF_Well  NMF_number_of_singlecells   NMF_compound  NMF_dose  \
# 0          1     C-02                        180  Staurosporine       0.0
# 1          1     C-02                        180  Staurosporine       0.0
# 2          1     C-02                        180  Staurosporine       0.0
# 3          1     C-02                        180  Staurosporine       0.0
# 4          1     C-02                        180  Staurosporine       0.0
#
#   NMF_control  NMF_ImageNumber NMF_FOV  NMF_Time  \
# 0    negative                1    0001       0.0
# 1    negative                1    0001       0.0
# 2    negative                1    0001       0.0
# 3    negative                1    0001       0.0
# 4    negative                1    0001       0.0
#
#    NMF_Cells_Number_Object_Number  ...  \
# 0                               6  ...
# 1                               7  ...
# 2                               9  ...
# 3                              11  ...
# 4                              12  ...
#
#    Nuclei_Texture_Correlation_CL_561_3_00_256  \
# 0                                    1.627355
# 1                                   -0.924724
# 2                                   -0.833578
# 3                                    0.168607
# 4                                   -0.912043
#
#    Nuclei_Texture_Correlation_CL_561_3_01_256  \
# 0                                    1.501131
# 1                                    1.501131
# 2                                   -0.793186
# 3                                    0.280239
# 4                                   -0.880947
#
#    Nuclei_Texture_Correlation_CL_561_3_02_256  \
# 0                                   -0.845063
# 1                                    1.562230
# 2                                   -0.782806
# 3                                   -0.001959
# 4                                   -0.864179
#
#    Nuclei_Texture_Correlation_CL_561_3_03_256  \
# 0                                   -0.608430
# 1                                   -0.701880
# 2                                   -0.572324
# 3                                   -0.330995
# 4                                   -0.630945
#
#    Nuclei_Texture_DifferenceVariance_CL_488_1_3_01_256  \
# 0                                           1.292035
# 1                                           0.886759
# 2                                           1.292035
# 3                                          -1.316472
# 4                                          -0.924705
#
#    Nuclei_Texture_DifferenceVariance_CL_488_2_3_03_256  \
# 0                                          -1.456748
# 1                                           0.827159
# 2                                          -1.456748
# 3                                           0.573392
# 4                                           0.375017
#
#   Nuclei_Texture_InverseDifferenceMoment_CL_561_3_03_256  \
# 0                                           0.557835
# 1                                           0.436105
# 2                                          -2.479875
# 3                                           0.124740
# 4                                           0.527587
#
#   Nuclei_Texture_SumAverage_CL_488_1_3_01_256  \
# 0                                   -0.390739
# 1                                   -0.390739
# 2                                   -0.390739
# 3                                    0.094856
# 4                                   -0.077278
#
#   Nuclei_Texture_SumAverage_CL_488_2_3_00_256  \
# 0                                   -1.476686
# 1                                    0.367550
# 2                                   -1.476686
# 3                                    0.367550
# 4                                    0.394278
#
#   Nuclei_Texture_SumAverage_CL_561_3_01_256
# 0                                  0.096642
# 1                                  0.096642
# 2                                 -2.420632
# 3                                  0.881523
# 4                                  0.189384
#
# [5 rows x 882 columns]
